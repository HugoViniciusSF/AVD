# %% [markdown]
# <a href="https://colab.research.google.com/github/HugoViniciusSF/AVD/blob/main/Hugo_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Bibliotecas

# %%
# !pip install --upgrade gdown

# %%
# utilizar os Dataframes do Pandas para manipular as instâncias
import pandas as pd
# matplotlib para visualizar
import matplotlib.pyplot as plt
# gdown para baixar os dados
import gdown
plt.style.use('ggplot')

# %% [markdown]
# # DataFrame do .CSV

# %%
df = pd.read_csv('/Video_Games.csv')
df.head()
# Out:
#    index                      Name Platform  Year_of_Release         Genre  \
# 0      0                Wii Sports      Wii           2006.0        Sports
# 1      1         Super Mario Bros.      NES           1985.0      Platform
# 2      2            Mario Kart Wii      Wii           2008.0        Racing
# 3      3         Wii Sports Resort      Wii           2009.0        Sports
# 4      4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
#
#   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0  Nintendo     41.36     28.96      3.77         8.45         82.53
# 1  Nintendo     29.08      3.58      6.81         0.77         40.24
# 2  Nintendo     15.68     12.76      3.79         3.29         35.52
# 3  Nintendo     15.61     10.93      3.28         2.95         32.77
# 4  Nintendo     11.27      8.89     10.22         1.00         31.37
#
#    Critic_Score  Critic_Count User_Score  User_Count Developer Rating
# ...

# %%
df.shape
# Out:
# (16928, 17)

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16928 entries, 0 to 16927
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            16928 non-null  int64
#  1   Name             16926 non-null  object
#  2   Platform         16928 non-null  object
#  3   Year_of_Release  16655 non-null  float64
#  4   Genre            16926 non-null  object
#  5   Publisher        16873 non-null  object
#  6   NA_Sales         16928 non-null  float64
#  7   EU_Sales         16928 non-null  float64
#  8   JP_Sales         16928 non-null  float64
#  9   Other_Sales      16928 non-null  float64
#  10  Global_Sales     16928 non-null  float64
#  11  Critic_Score     8260 non-null   float64
#  12  Critic_Count     8260 non-null   float64
#  13  User_Score       10159 non-null  object
#  14  User_Count       7718 non-null   float64
#  15  Developer        10240 non-null  object
# ...

# %% [markdown]
# #Separando em um novo DataFrame com os elementos desejados

# %%
gData = df.loc[: , ['Platform' , 'Genre' , 'Publisher' , 'Critic_Score', 'User_Score']]
gData.head(10000)
# Out:
#      Platform         Genre                     Publisher  Critic_Score  \
# 0         Wii        Sports                      Nintendo          76.0
# 1         NES      Platform                      Nintendo           NaN
# 2         Wii        Racing                      Nintendo          82.0
# 3         Wii        Sports                      Nintendo          80.0
# 4          GB  Role-Playing                      Nintendo           NaN
# ...       ...           ...                           ...           ...
# 9995      GBA        Racing                           THQ          77.0
# 9996      PS3        Action                          Sega           NaN
# 9997      PS3          Misc  Konami Digital Entertainment           NaN
# 9998      PS3        Action                    Tecmo Koei          70.0
# 9999      PS2      Fighting                    Tecmo Koei           NaN
#
#      User_Score
# 0             8
# 1           NaN
# 2           8.3
# 3             8
# ...

# %%
gData.info()
gData.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16928 entries, 0 to 16927
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Platform      16928 non-null  object
#  1   Genre         16926 non-null  object
#  2   Publisher     16873 non-null  object
#  3   Critic_Score  8260 non-null   float64
#  4   User_Score    10159 non-null  object
# dtypes: float64(1), object(4)
# memory usage: 661.4+ KB
#        Critic_Score
# count   8260.000000
# mean      69.037893
# std       13.943198
# min       13.000000
# 25%       60.000000
# 50%       71.000000
# 75%       79.000000
# max       98.000000

# %%
len(gData['Platform'].unique())
# Out:
# 31

# %%
len(gData['Genre'].unique())
# Out:
# 13

# %%
len(gData['Publisher'].unique())
# Out:
# 582

# %% [markdown]
# # Quantidade de jogos feitos pelas publicadoras

# %%
gData['Publisher'].value_counts().head(30)
# Out:
# Publisher
# Electronic Arts                           1389
# Activision                                1003
# Namco Bandai Games                         952
# Ubisoft                                    948
# Konami Digital Entertainment               839
# THQ                                        722
# Nintendo                                   721
# Sony Computer Entertainment                701
# Sega                                       647
# Take-Two Interactive                       427
# Capcom                                     392
# Atari                                      372
# Tecmo Koei                                 352
# Square Enix                                238
# Warner Bros. Interactive Entertainment     237
# Disney Interactive Studios                 224
# Eidos Interactive                          203
# Unknown                                    201
# Midway Games                               199
# Microsoft Game Studios                     193
# ...

# %% [markdown]
# Filtragem para descrever os valores da Coluna Gênero (Genre)

# %%
# Excluir os valores NaN da coluna 'Genre'
gData_sem_nan = gData.dropna(subset=['Genre'])

# Listar os gêneros únicos após remover os NaN
generos_sem_nan = gData_sem_nan['Genre'].unique()
print(generos_sem_nan)
# Out:
# ['Sports' 'Platform' 'Racing' 'Role-Playing' 'Puzzle' 'Misc' 'Shooter'
#  'Simulation' 'Action' 'Fighting' 'Adventure' 'Strategy']

# %% [markdown]
# Quantidade de jogos por genero

# %%
# Contar a quantidade de jogos por gênero
quantidade_por_genero = gData_sem_nan['Genre'].value_counts()

print(quantidade_por_genero)
# Out:
# Genre
# Action          3410
# Sports          2380
# Misc            1773
# Role-Playing    1519
# Shooter         1347
# Adventure       1313
# Racing          1266
# Platform         904
# Simulation       880
# Fighting         863
# Strategy         689
# Puzzle           582
# Name: count, dtype: int64

# %% [markdown]
# Listagem das plataformas sem o valor nulo

# %%
# Excluir os valores NaN da coluna 'Platform'
gData_sem_nan = gData.dropna(subset=['Platform'])

# Listar os gêneros únicos após remover os NaN
plataforma_sem_nan = gData_sem_nan['Platform'].unique()
print(plataforma_sem_nan)
# Out:
# ['Wii' 'NES' 'GB' 'DS' 'X360' 'PS3' 'PS2' 'SNES' 'GBA' 'PS4' '3DS' 'N64'
#  'PS' 'XB' 'PC' '2600' 'PSP' 'XOne' 'WiiU' 'GC' 'GEN' 'DC' 'PSV' 'SAT'
#  'SCD' 'WS' 'NG' 'TG16' '3DO' 'GG' 'PCFX']

# %% [markdown]
# Listagem das plataformas

# %%
gData['Platform'].value_counts().head(31)
# Out:
# Platform
# PS2     2188
# DS      2164
# PS3     1359
# Wii     1337
# X360    1280
# PSP     1216
# PS      1214
# PC       982
# GBA      839
# XB       832
# GC       564
# 3DS      530
# PSV      436
# PS4      399
# N64      325
# XOne     253
# SNES     242
# SAT      175
# WiiU     148
# 2600     136
# GB        99
# NES       98
# DC        52
# GEN       29
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: count, dtype: int64

# %% [markdown]
# Listagem de quais plataformas tem em cada genero

# %%
# Exclua os valores NaN das colunas 'Genre' e 'Platform'
gData_sem_nan = gData.dropna(subset=['Genre', 'Platform'])

# Agrupe os dados por gênero
grupos_por_genero = gData_sem_nan.groupby('Genre')

# Itere sobre os grupos e imprima as plataformas associadas a cada gênero
for genero, grupo in grupos_por_genero:
    print(f"Gênero: {genero}")
    print(f"Plataformas: {grupo['Platform'].unique()}")
    print()
# Out:
# Gênero: Action
# Plataformas: ['PS3' 'PS2' 'X360' 'PS4' 'DS' 'PSP' 'N64' 'Wii' 'NES' 'PS' 'XOne' 'SNES'
#  'GC' '3DS' 'GB' 'XB' 'GBA' 'GEN' 'PC' '2600' 'WiiU' 'PSV' 'DC' 'SAT']
#
# Gênero: Adventure
# Plataformas: ['GB' 'X360' 'PS3' 'NES' 'PS' 'DS' 'PC' 'GBA' 'PS2' 'GC' 'PS4' 'XOne'
#  'Wii' '2600' 'DC' 'PSP' '3DS' 'SNES' 'XB' 'PSV' 'SAT' 'N64' 'TG16' 'GEN'
#  'WiiU' '3DO']
#
# Gênero: Fighting
# Plataformas: ['Wii' '3DS' 'PS' 'GC' 'SNES' 'N64' 'WiiU' 'PS3' 'PS2' 'NES' 'X360' 'PS4'
#  'GEN' 'PSP' 'SAT' 'XB' 'XOne' 'GBA' '2600' 'DS' 'PSV' 'DC' 'NG' 'PC']
#
# Gênero: Misc
# Plataformas: ['Wii' 'X360' 'DS' 'GB' 'PS3' 'PS2' 'WiiU' 'PS4' 'GBA' 'PS' 'PC' 'XOne'
#  'SNES' 'N64' 'GC' 'NES' 'PSV' '3DS' 'XB' '2600' 'PSP' 'SAT' 'SCD' 'GEN']
#
# Gênero: Platform
# Plataformas: ['NES' 'DS' 'Wii' 'SNES' 'GB' 'N64' '3DS' 'PS' 'GC' 'GEN' 'PS3' 'GBA'
#  'PS2' 'WiiU' '2600' 'PSP' 'DC' 'PS4' 'SCD' 'X360' 'PSV' 'XB' 'SAT' 'XOne'
#  'PC' 'GG']
#
# Gênero: Puzzle
# ...

# %% [markdown]
# Media do meta_score de cada genero por plataforma

# %%
# Exclua os valores NaN das colunas 'Genre', 'Platform', 'Critic_Score' e 'User_Score'
gData_sem_nan = gData.dropna(subset=['Genre', 'Platform', 'Critic_Score', 'User_Score']).copy()

# Converta o User_Score para o tipo numérico (float) e multiplique por 10
gData_sem_nan.loc[:, 'User_Score'] = pd.to_numeric(gData_sem_nan['User_Score'], errors='coerce') * 10

# Calcule o meta_score como a média entre Critic_Score e User_Score
gData_sem_nan.loc[:, 'Meta_Score'] = (gData_sem_nan['Critic_Score'] + gData_sem_nan['User_Score']) / 2

# Agrupe os dados por gênero e plataforma
grupos_por_genero_plataforma = gData_sem_nan.groupby(['Genre', 'Platform'])

# Calcule a média do Meta_Score para cada grupo
media_por_genero_plataforma = grupos_por_genero_plataforma['Meta_Score'].mean()

print(media_por_genero_plataforma.round)
# Out:
# <bound method Series.round of Genre     Platform
# Action    3DS         64.686441
#           DS          62.608974
#           GBA         69.160714
#           GC          72.621429
#           PC          72.197842
#                         ...
# Strategy  Wii         66.166667
#           WiiU             87.0
#           X360        71.571429
#           XB          76.230769
#           XOne             72.5
# Name: Meta_Score, Length: 197, dtype: object>

# %% [markdown]
# Aqui eu sei quanto cada publicadora participou na media do do meta_score do genero por plataforma.

# %%
def calcular_participacoes(dados, genero, plataforma):
    # Filtrar os dados apenas para o gênero e plataforma específicos, removendo valores NaN
    dados_genero_plataforma = dados[(dados['Genre'] == genero) & (dados['Platform'] == plataforma)].dropna(subset=['Meta_Score'])

    # Obter a lista única de publicadoras que lançaram jogos nessa plataforma e gênero
    publicadoras = dados_genero_plataforma['Publisher'].unique()

    # Calcular a soma total do Meta_Score para o gênero e plataforma específicos
    soma_total_meta_score_plataforma = dados_genero_plataforma['Meta_Score'].sum()

    # Criar um dicionário para armazenar as participações percentuais de cada publicadora
    participacao_publicadoras = {}

    # Iterar sobre cada publicadora
    for publicadora in publicadoras:
        # Filtrar os dados para os jogos dessa publicadora, removendo valores NaN
        jogos_publicadora = dados_genero_plataforma[dados_genero_plataforma['Publisher'] == publicadora].dropna(subset=['Meta_Score'])

        # Calcular a soma do Meta_Score apenas para os jogos dessa publicadora
        soma_meta_score_publicadora = jogos_publicadora['Meta_Score'].sum()

        # Calcular a participação percentual da publicadora no valor total do Meta_Score para o gênero e plataforma específicos
        participacao_publicadora = (soma_meta_score_publicadora / soma_total_meta_score_plataforma) * 100

        # Armazenar a participação percentual no dicionário
        participacao_publicadoras[publicadora] = participacao_publicadora

    return participacao_publicadoras


def imprimir_participacoes(participacao_publicadoras, genero, plataforma):
    # Imprimir as participações percentuais de cada publicadora
    for publicadora, participacao in participacao_publicadoras.items():
        print(f"A participação da publicadora '{publicadora}' no valor total do Meta_Score para o gênero '{genero}' na plataforma '{plataforma}' é de {participacao:.2f}%.")

    # Calcular e imprimir a soma das participações
    soma_participacoes = sum(participacao_publicadoras.values())
    print(f"\nA soma das participações é de {soma_participacoes:.2f}%.")


# Escolha a plataforma e o gênero específicos
plataforma_especifica = 'PS4'
genero_especifico = 'Action'

# Calcular as participações
participacao_publicadoras = calcular_participacoes(gData_sem_nan, genero_especifico, plataforma_especifica)

# Imprimir as participações
imprimir_participacoes(participacao_publicadoras, genero_especifico, plataforma_especifica)
# Out:
# A participação da publicadora 'Take-Two Interactive' no valor total do Meta_Score para o gênero 'Action' na plataforma 'PS4' é de 2.52%.
# A participação da publicadora 'Sony Computer Entertainment' no valor total do Meta_Score para o gênero 'Action' na plataforma 'PS4' é de 8.18%.
# A participação da publicadora 'Ubisoft' no valor total do Meta_Score para o gênero 'Action' na plataforma 'PS4' é de 13.35%.
# A participação da publicadora 'Warner Bros. Interactive Entertainment' no valor total do Meta_Score para o gênero 'Action' na plataforma 'PS4' é de 17.76%.
# A participação da publicadora 'Konami Digital Entertainment' no valor total do Meta_Score para o gênero 'Action' na plataforma 'PS4' é de 2.63%.
# A participação da publicadora 'Square Enix' no valor total do Meta_Score para o gênero 'Action' na plataforma 'PS4' é de 4.79%.
# A participação da publicadora 'Bethesda Softworks' no valor total do Meta_Score para o gênero 'Action' na plataforma 'PS4' é de 3.95%.
# ...

# %%
def calcular_participacoes(dados, genero, plataforma):
    # Filtrar os dados apenas para o gênero e plataforma específicos, removendo valores NaN
    dados_genero_plataforma = dados[(dados['Genre'] == genero) & (dados['Platform'] == plataforma)].dropna(subset=['Meta_Score'])

    # Obter a lista única de publicadoras que lançaram jogos nessa plataforma e gênero
    publicadoras = dados_genero_plataforma['Publisher'].unique()

    # Calcular a soma total do Meta_Score para o gênero e plataforma específicos
    soma_total_meta_score_plataforma = dados_genero_plataforma['Meta_Score'].sum()

    # Criar um dicionário para armazenar as participações percentuais de cada publicadora
    participacao_publicadoras = {}

    # Iterar sobre cada publicadora
    for publicadora in publicadoras:
        # Filtrar os dados para os jogos dessa publicadora, removendo valores NaN
        jogos_publicadora = dados_genero_plataforma[dados_genero_plataforma['Publisher'] == publicadora].dropna(subset=['Meta_Score'])

        # Calcular a soma do Meta_Score apenas para os jogos dessa publicadora, se houver
        if not jogos_publicadora.empty:
            soma_meta_score_publicadora = jogos_publicadora['Meta_Score'].sum()

            # Calcular a participação percentual da publicadora no valor total do Meta_Score para o gênero e plataforma específicos
            participacao_publicadora = (soma_meta_score_publicadora / soma_total_meta_score_plataforma) * 100

            # Armazenar a participação percentual no dicionário
            participacao_publicadoras[publicadora] = participacao_publicadora

    return participacao_publicadoras


def imprimir_participacoes(participacao_publicadoras, genero, plataforma):
    # Imprimir as participações percentuais de cada publicadora
    for publicadora, participacao in participacao_publicadoras.items():
        print(f"A participação da publicadora '{publicadora}' no valor total do Meta_Score para o gênero '{genero}' na plataforma '{plataforma}' é de {participacao:.2f}%.")

    # Calcular e imprimir a soma das participações
    soma_participacoes = sum(participacao_publicadoras.values())
    print(f"\nA soma das participações é de {soma_participacoes:.2f}%.")


# Escolha a plataforma e o gênero específicos
plataforma_especifica = '3DS'
genero_especifico = 'Action'

# Calcular as participações
participacao_publicadoras = calcular_participacoes(gData_sem_nan, genero_especifico, plataforma_especifica)

# Imprimir as participações
imprimir_participacoes(participacao_publicadoras, genero_especifico, plataforma_especifica)
# Out:
# A participação da publicadora 'Nintendo' no valor total do Meta_Score para o gênero 'Action' na plataforma '3DS' é de 23.56%.
# A participação da publicadora 'Square Enix' no valor total do Meta_Score para o gênero 'Action' na plataforma '3DS' é de 2.06%.
# A participação da publicadora 'LucasArts' no valor total do Meta_Score para o gênero 'Action' na plataforma '3DS' é de 1.68%.
# A participação da publicadora 'Marvelous Entertainment' no valor total do Meta_Score para o gênero 'Action' na plataforma '3DS' é de 3.69%.
# A participação da publicadora 'Warner Bros. Interactive Entertainment' no valor total do Meta_Score para o gênero 'Action' na plataforma '3DS' é de 16.74%.
# A participação da publicadora 'Capcom' no valor total do Meta_Score para o gênero 'Action' na plataforma '3DS' é de 3.88%.
# A participação da publicadora 'Activision' no valor total do Meta_Score para o gênero 'Action' na plataforma '3DS' é de 7.47%.
# ...

# %%
# Filtrar os jogos da Atari no gênero "Action" e na plataforma "Wii"
jogos_atari = gData[(gData['Publisher'] == 'Atari') & (gData['Genre'] == 'Action') & (gData['Platform'] == 'Wii')]

# Imprimir os jogos encontrados
print(jogos_atari[['Genre', 'Platform']])
# Out:
#        Genre Platform
# 2413  Action      Wii
# 9369  Action      Wii

# %%
Publicadora = 'Nintendo'
Genero = 'Action'
Plataforma = '3DS'
# Filtrar os jogos de qualquer publicadora em qualquer gênero e em qualquer plataforma
jogos_publicados = gData[(gData['Publisher'] == Publicadora) & (gData['Genre'] == Genero) & (gData['Platform'] == Plataforma)]

# Imprimir os jogos encontrados
print(jogos_publicados[['Genre', 'Platform']])
# Out:
#         Genre Platform
# 235    Action      3DS
# 259    Action      3DS
# 448    Action      3DS
# 677    Action      3DS
# 1551   Action      3DS
# 1784   Action      3DS
# 1817   Action      3DS
# 2219   Action      3DS
# 3788   Action      3DS
# 4068   Action      3DS
# 4206   Action      3DS
# 4488   Action      3DS
# 5428   Action      3DS
# 6337   Action      3DS
# 6946   Action      3DS
# 7487   Action      3DS
# 10027  Action      3DS
# 11060  Action      3DS
# 13215  Action      3DS
# 13944  Action      3DS
# 16657  Action      3DS

# %%
Publicadora = 'Atari'
Genero = 'Action'
Plataforma = '2600'
# Filtrar os jogos de qualquer publicadora em qualquer gênero e em qualquer plataforma
jogos_publicados = gData[(gData['Publisher'] == Publicadora) & (gData['Genre'] == Genero) & (gData['Platform'] == Plataforma)]

# Imprimir os jogos encontrados
print(jogos_publicados[['Genre', 'Platform']])
# Out:
#        Genre Platform
# 866   Action     2600
# 1585  Action     2600
# 2656  Action     2600
# 3941  Action     2600
# 4003  Action     2600
# 4220  Action     2600
# 4245  Action     2600
# 4337  Action     2600
# 5050  Action     2600
# 5800  Action     2600
# 6300  Action     2600
# 7166  Action     2600
# 9096  Action     2600
